# %%
Context
A fictional dataset for exploratory data analysis (EDA) and to test simple prediction models.
This toy dataset features 150000 rows and 6 columns.

Columns
Note: All data is fictional. The data has been generated so that their distributions are convenient for statistical analysis.
Number: A simple index number for each row
City: The location of a person (Dallas, New York City, Los Angeles, Mountain View, Boston, Washington D.C., San Diego and Austin)
Gender: Gender of a person (Male or Female)
Age: The age of a person (Ranging from 25 to 65 years)
Income: Annual income of a person (Ranging from -674 to 177175)
Illness: Is the person Ill? (Yes or No)
# Out:
#   File "<ipython-input-1-feaa209304e6>", line 2
#     A fictional dataset for exploratory data analysis (EDA) and to test simple prediction models.
#               ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# Будем анализировать данные только на обучающей выборке
data = pd.read_csv('toy_dataset.csv', sep=",")

# %%
# Первые 5 строк датасета
data.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %%
# Размер датасета 
data.shape
# Out:
# (150000, 6)

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 150000

# %%
# Список колонок
data.columns
# Out:
# Index(['Number', 'City', 'Gender', 'Age', 'Income', 'Illness'], dtype='object')

# %%
# Список колонок с типами данных
data.dtypes
# Out:
# Number       int64
# City        object
# Gender      object
# Age          int64
# Income     float64
# Illness     object
# dtype: object

# %%
# Проверим наличие пустых значений
# Цикл по колонкам датасета
for col in data.columns:
    # Количество пустых значений - все значения заполнены
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
# Out:
# Number - 0
# City - 0
# Gender - 0
# Age - 0
# Income - 0
# Illness - 0

# %%
# Основные статистические характеристки набора данных
data.describe()
# Out:
#               Number            Age         Income
# count  150000.000000  150000.000000  150000.000000
# mean    75000.500000      44.950200   91252.798273
# std     43301.414527      11.572486   24989.500948
# min         1.000000      25.000000    -654.000000
# 25%     37500.750000      35.000000   80867.750000
# 50%     75000.500000      45.000000   93655.000000
# 75%    112500.250000      55.000000  104519.000000
# max    150000.000000      65.000000  177157.000000

# %%
# Определим уникальные значения для целевого признака
data['Illness'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
dct = {'Yes': 1, 'No': 0}
data['Illness_count'] = data['Illness'].map(dct)
data
# Out:
#         Number    City  Gender  Age    Income Illness  Illness_count
# 0            1  Dallas    Male   41   40367.0      No              0
# 1            2  Dallas    Male   54   45084.0      No              0
# 2            3  Dallas    Male   42   52483.0      No              0
# 3            4  Dallas    Male   40   40941.0      No              0
# 4            5  Dallas    Male   46   50289.0      No              0
# 5            6  Dallas  Female   36   50786.0      No              0
# 6            7  Dallas  Female   32   33155.0      No              0
# 7            8  Dallas    Male   39   30914.0      No              0
# 8            9  Dallas    Male   51   68667.0      No              0
# 9           10  Dallas  Female   30   50082.0      No              0
# 10          11  Dallas  Female   48   41524.0     Yes              1
# 11          12  Dallas    Male   47   54777.0      No              0
# 12          13  Dallas    Male   46   62749.0      No              0
# 13          14  Dallas  Female   42   50894.0      No              0
# 14          15  Dallas  Female   61   38429.0      No              0
# 15          16  Dallas    Male   43   34074.0      No              0
# 16          17  Dallas    Male   27   50398.0      No              0
# 17          18  Dallas    Male   38   46373.0     Yes              1
# 18          19  Dallas    Male   47   51137.0      No              0
# 19          20  Dallas  Female   35   23688.0      No              0
# 20          21  Dallas    Male   57   17378.0      No              0
# 21          22  Dallas    Male   33   45919.0      No              0
# 22          23  Dallas  Female   33   23001.0      No              0
# 23          24  Dallas  Female   27   34292.0     Yes              1
# 24          25  Dallas    Male   58   55190.0      No              0
# 25          26  Dallas    Male   64   26169.0      No              0
# 26          27  Dallas    Male   58   57322.0      No              0
# 27          28  Dallas    Male   44   61704.0      No              0
# 28          29  Dallas    Male   34   53619.0      No              0
# 29          30  Dallas    Male   45   47421.0     Yes              1
# ...        ...     ...     ...  ...       ...     ...            ...
# 149970  149971  Austin  Female   63   99950.0      No              0
# 149971  149972  Austin  Female   30   76928.0      No              0
# 149972  149973  Austin    Male   46   84395.0      No              0
# 149973  149974  Austin  Female   52   77272.0      No              0
# 149974  149975  Austin  Female   39   90430.0      No              0
# 149975  149976  Austin  Female   51   92132.0      No              0
# 149976  149977  Austin    Male   49   91519.0      No              0
# 149977  149978  Austin    Male   51  107123.0      No              0
# 149978  149979  Austin    Male   58  100949.0      No              0
# 149979  149980  Austin    Male   43   86737.0      No              0
# 149980  149981  Austin  Female   53   89384.0     Yes              1
# 149981  149982  Austin    Male   50   77134.0      No              0
# 149982  149983  Austin  Female   47   92157.0      No              0
# 149983  149984  Austin  Female   25   92482.0      No              0
# 149984  149985  Austin    Male   51   99075.0      No              0
# 149985  149986  Austin  Female   25   74947.0      No              0
# 149986  149987  Austin  Female   63   80381.0      No              0
# 149987  149988  Austin  Female   55   62501.0      No              0
# 149988  149989  Austin  Female   26   77823.0      No              0
# 149989  149990  Austin    Male   52   83688.0      No              0
# 149990  149991  Austin  Female   26   82163.0      No              0
# 149991  149992  Austin    Male   51   97510.0      No              0
# 149992  149993  Austin    Male   37   88408.0      No              0
# 149993  149994  Austin    Male   64   89906.0      No              0
# 149994  149995  Austin  Female   37  106097.0      No              0
# 149995  149996  Austin    Male   48   93669.0      No              0
# 149996  149997  Austin    Male   25   96748.0      No              0
# 149997  149998  Austin    Male   26  111885.0      No              0
# 149998  149999  Austin    Male   25  111878.0      No              0
# 149999  150000  Austin  Female   37   87251.0      No              0
#
# [150000 rows x 7 columns]

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(ax=ax, x='Age', y='Income', data=data)

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue = "Illness")
# Out:
# C:\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
data.corr(method='pearson')
# Out:
#                  Number       Age    Income  Illness_count
# Number         1.000000 -0.003448  0.410460       0.003138
# Age           -0.003448  1.000000 -0.001318       0.001811
# Income         0.410460 -0.001318  1.000000       0.000298
# Illness_count  0.003138  0.001811  0.000298       1.000000

# %%
sns.heatmap(data.corr())

# %%
# Вывод значений в ячейках
sns.heatmap(data.corr(), annot=True, fmt='.3f')
